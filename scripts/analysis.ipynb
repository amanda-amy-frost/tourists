# %%
import polars as pl
import altair as alt
from init_dataframes import *
from scaled_dataframes import *

# %%
charts = []
for _, df in regions_df.items():
    charts.append(
        alt.Chart(df).mark_point(tooltip=True).encode(
            x='str_year',
            y='scaled',
            color='country'
        )
        .properties(width=500)
        .configure_scale(zero=False)
    )

# %%
charts[0]
# Out:
# alt.Chart(...)

# %%
charts[1]
# Out:
# alt.Chart(...)

# %%
charts[2]
# Out:
# alt.Chart(...)

# %%
charts[3]
# Out:
# alt.Chart(...)

# %%
charts[4]
# Out:
# alt.Chart(...)
